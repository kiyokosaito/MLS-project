# %% [markdown]
# # Scikit-Learn
# ## This notebook will cover below
# ##### 1.Overview of the sckit-learn
# ##### 2.3 algorithms with plots and visualisations

# %% [markdown]
# ## 1. Overview of the sckit-learn
#
# # Scikit-learn is one of machine learning library which is buit in Python. It is an open source that anyone can use for free and the update and development of library is ongoing. Also a sample toy data sets and real workd datasets are attacheted thus anyone can try and learn machine learning. Therefore, it is widely available in the world and a great way to learn machine learning with this library. [1][2]

# %% [markdown]
# ## There are 4 categories in this library, with the cheat sheet, it is easy to identify which algorythm to be used. Here is the 4 categories and the algorithm cheat sheet. [3]

# %% [markdown]
# ### There are many algothryms in this library which divided into 4 categories below.
#
# #### Classification     <e.g. SGD Classifier, KNEighbors Classifier>
# #### Regression         <e.g. SGD Regressor, Lasso>
# #### Dimensionality     <e.g reduction Kernel approximation, LLE>
# #### Clustering         <e.g.KMeans, MeanShift>

# %%
from IPython.display import Image
from IPython.core.display import HTML
Image(url = "https://scikit-learn.org/stable/_static/ml_map.png", width =1000, height = 1000)
# Out:
# <img src="https://scikit-learn.org/stable/_static/ml_map.png" width="1000" height="1000"/>

# %% [markdown]
# ##### 2.3 algorithms with plots and visualisations
# ###### 1. Classification Wine recognition datasets
# ###### 2.
# ###### 3.

# %% [markdown]
# ###### 1. Classification Wine recognition datasets
#
# ########### https://obgynai.com/wine-supervised-learning/

# %%
#Numerical array.
import numpy as np

#Data frames. 
import pandas as pd 

#plotting.
import matplotlib.pyplot as plt

#logistic regression.
import sklearn.linear_model as lm

#K nearest neaigbours.
import sklearn.neighbors as nei

#Helper functions.
import sklearn.model_selection as mod

#Fansier, statical plots.
import seaborn as sns

# %%
#Standar plot size.
plt.rcParams['figure.figsize']=(15,10)

#Standard colour scheme.
plt.style.use('ggplot')

# %% [markdown]
# ### Wine dataset

# %%
# Load the irish data set from a URL
data = pd.read_csv('https://github.com/kiyokosaito/MLS-project/blob/main/wine.csv', error_bad_lines=False)
# Out:
# b'Skipping line 118: expected 1 fields, saw 2\nSkipping line 137: expected 1 fields, saw 370\nSkipping line 138: expected 1 fields, saw 2\nSkipping line 153: expected 1 fields, saw 3\nSkipping line 206: expected 1 fields, saw 3\nSkipping line 220: expected 1 fields, saw 6\nSkipping line 257: expected 1 fields, saw 4\nSkipping line 261: expected 1 fields, saw 2\nSkipping line 278: expected 1 fields, saw 2\nSkipping line 279: expected 1 fields, saw 2\nSkipping line 285: expected 1 fields, saw 2\nSkipping line 288: expected 1 fields, saw 2\nSkipping line 296: expected 1 fields, saw 4\nSkipping line 302: expected 1 fields, saw 2\nSkipping line 307: expected 1 fields, saw 2\nSkipping line 308: expected 1 fields, saw 2\nSkipping line 309: expected 1 fields, saw 2\nSkipping line 310: expected 1 fields, saw 2\nSkipping line 311: expected 1 fields, saw 2\nSkipping line 317: expected 1 fields, saw 2\nSkipping line 318: expected 1 fields, saw 2\nSkipping line 319: expected 1 fields, saw 2\nSkipping line 320: expected 1 fields, saw 2\nSkipping line 327: expected 1 fields, saw 2\nSkipping line 335: expected 1 fields, saw 4\nSkipping line 340: expected 1 fields, saw 2\nSkipping line 343: expected 1 fields, saw 2\nSkipping line 344: expected 1 fields, saw 2\nSkipping line 348: expected 1 fields, saw 2\nSkipping line 369: expected 1 fields, saw 2\nSkipping line 568: expected 1 fields, saw 6\nSkipping line 569: expected 1 fields, saw 3\nSkipping line 576: expected 1 fields, saw 6\nSkipping line 577: expected 1 fields, saw 6\nSkipping line 665: expected 1 fields, saw 6\nSkipping line 680: expected 1 fields, saw 6\nSkipping line 699: expected 1 fields, saw 6\nSkipping line 737: expected 1 fields, saw 3\nSkipping line 748: expected 1 fields, saw 3\nSkipping line 759: expected 1 fields, saw 3\nSkipping line 770: expected 1 fields, saw 3\nSkipping line 781: expected 1 fields, saw 3\nSkipping line 792: expected 1 fields, saw 3\nSkipping line 803: expected 1 fields, saw 3\nSkipping line 814: expected 1 fields, saw 3\nSkipping line 1068: expected 1 fields, saw 7\nSkipping line 1136: expected 1 fields, saw 2\nSkipping line 1231: expected 1 fields, saw 2\nSkipping line 1234: expected 1 fields, saw 2\nSkipping line 1267: expected 1 fields, saw 2\nSkipping line 1269: expected 1 fields, saw 2\nSkipping line 1308: expected 1 fields, saw 12\nSkipping line 1314: expected 1 fields, saw 12\nSkipping line 1318: expected 1 fields, saw 12\nSkipping line 1322: expected 1 fields, saw 12\nSkipping line 1326: expected 1 fields, saw 12\nSkipping line 1330: expected 1 fields, saw 12\nSkipping line 1334: expected 1 fields, saw 12\nSkipping line 1338: expected 1 fields, saw 12\nSkipping line 1342: expected 1 fields, saw 12\nSkipping line 1346: expected 1 fields, saw 12\nSkipping line 1350: expected 1 fields, saw 12\nSkipping line 1354: expected 1 fields, saw 12\nSkipping line 1358: expected 1 fields, saw 12\nSkipping line 1362: expected 1 fields, saw 12\nSkipping line 1366: expected 1 fields, saw 12\nSkipping line 1370: expected 1 fields, saw 12\nSkipping line 1374: expected 1 fields, saw 12\nSkipping line 1378: expected 1 fields, saw 12\nSkipping line 1382: expected 1 fields, saw 12\nSkipping line 1386: expected 1 fields, saw 12\nSkipping line 1390: expected 1 fields, saw 12\nSkipping line 1394: expected 1 fields, saw 12\nSkipping line 1398: expected 1 fields, saw 12\nSkipping line 1402: expected 1 fields, saw 12\nSkipping line 1406: expected 1 fields, saw 12\nSkipping line 1410: expected 1 fields, saw 12\nSkipping line 1414: expected 1 fields, saw 12\nSkipping line 1418: expected 1 fields, saw 12\nSkipping line 1422: expected 1 fields, saw 12\nSkipping line 1426: expected 1 fields, saw 12\nSkipping line 1430: expected 1 fields, saw 12\nSkipping line 1434: expected 1 fields, saw 12\nSkipping line 1438: expected 1 fields, saw 12\nSkipping line 1442: expected 1 fields, saw 12\nSkipping line 1446: expected 1 fields, saw 12\nSkipping line 1450: expected 1 fields, saw 12\nSki ...

# %%
data.describe()
# Out:
#         <!DOCTYPE html>
# count              5805
# unique             3872
# top               </tr>
# freq               1599

# %%
data["target"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-aaf51e9bbf1f> in <module>
# ----> 1 data["target"]
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
y_all = pd.DataFrame(data["target"], columns = ["target"])
y_all = y_all.replace({0:'class_0', 1:'class_1', 2:'class_2'})
y_all.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fa41d53efd6f> in <module>
#       1 import pandas as pd
# ----> 2 y_all = pd.DataFrame(data["target"], columns = ["target"])
#       3 y_all = y_all.replace({0:'class_0', 1:'class_1', 2:'class_2'})
#       4 y_all.head()
#
# NameError: name 'data' is not defined

# %%
X_all= pd.DataFrame(data["data"],columns = data["feature_names"])
X_all.head()

# %%
X_all.describe()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size = 0.33, random_state=0)

# %%
train = pd.concat([X_train, y_train], axis=1, sort=False)

# %%
train, test =mod.train_test_split(X_all)

# %%
train.head()

# %%
train.info()

# %%
train.groupby("target").mean()

# %% [markdown]
# ####[1]https://scikit-learn.org/stable/
# ####[2]https://techacademy.jp/magazine/17375
# ####[3] https://stackoverflow.com/questions/32370281/how-to-embed-image-or-picture-in-jupyter-notebook-either-from-a-local-machine-o
